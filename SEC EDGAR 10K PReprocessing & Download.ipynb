# %% [markdown]
# # **Using EDGAR tools to download the 10k filings of the companies**

# %%
# !pip install edgartools

# %%
from edgar import set_identity

set_identity("Mr Example examplemaster@gmail.com")

# %%
from edgar import Company

apple = Company("AAPL")

# %%
apple.financials #Financial Summary
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                                Balance Sheet
#
#                                                        2023-09-30         2022-09-24         2021-09-25
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     ASSETS:
#     CURRENT ASSETS:
#       Cash and Cash Equivalents                    29,965,000,000     23,646,000,000
#       Short-term Investments
#       Other Current Assets                         14,695,000,000     21,223,000,000
#       Total Current Assets                        143,566,000,000    135,405,000,000
#
#     NONCURRENT ASSETS:
#       Marketable Securities                       100,544,000,000    120,805,000,000
#       Property, Plant and Equipment                43,715,000,000     42,117,000,000
#       Other Noncurrent Assets                      64,758,000,000     54,428,000,000
#       Total Noncurrent Assets                     209,017,000,000    217,350,000,000
#
#     Total Assets                                  352,583,000,000    352,755,000,000
#
#     LIABILITIES AND STOCKHOLDERS' EQUITY:
#     CURRENT LIABILITIES:
#       Accounts Payable                             62,611,000,000     64,115,000,000
#       Other Current Liabilities                    58,829,000,000     60,845,000,000
#       Deferred Revenue                              8,061,000,000      7,912,000,000
#       Commercial Paper                              5,985,000,000      9,982,000,000
#       Term Debt                                     9,822,000,000     11,128,000,000
#       Accrued Liabilities
#       Total Current Liabilities                   145,308,000,000    153,982,000,000
#
#     NONCURRENT LIABILITIES:
#       Non-current Long Term Debt                   95,281,000,000     98,959,000,000
#       Other Noncurrent Liabilities                 49,848,000,000     49,142,000,000
#       Total Noncurrent Liabilities                145,129,000,000    148,101,000,000
#
#     Total Liabilities                             290,437,000,000    302,083,000,000
#
#     STOCKHOLDERS' EQUITY:
#       Common Stock and paid-in Capital             73,812,000,000     64,849,000,000
#       Retained Earnings                              -214,000,000     -3,068,000,000
#       Accumulated Other Comprehensive Income      -11,452,000,000    -11,109,000,000
#       Total Stockholders' Equity                   62,146,000,000     50,672,000,000     63,090,000,000
#
#     Total Liabilities and Stockholders' Equity    352,583,000,000    352,755,000,000
#
#                                                 Cashflow Statement
#
#                                                                2023-09-30         2022-09-24         2021-09-25
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     OPERATING ACTIVITIES:
#       Net Income                                           96,995,000,000     99,803,000,000     94,680,000,000
#       Depreciation and Amortization                        11,519,000,000     11,104,000,000     11,284,000,000
#       Stock-based Compensation                             10,833,000,000      9,038,000,000      7,906,000,000
#       Foreign Currency Transaction Gain/Loss
#       Other Noncash Income/Expense                          2,227,000,000     -1,006,000,000      4,921,000,000
#       Changes in Other Current Assets
#       Changes in Accounts Payable                          -1,889,000,000      9,448,000,000     12,326,000,000
#       Changes in Inventories                                1,618,000,000     -1,484,000,000      2,642,000,000
#       Changes in Deferred Revenue
#       Net Cash Provided by Operating Activities           110,543,000,000    122,151,000,000    104,038,000,000
#
#     INVESTING ACTIVITIES:
#       Purchases of Marketable Securities                   29,513,000,000     76,923,000,000    109,558,000,000
#       Proceeds from Maturities of Marketable               39,686,000,000     29,917,000,000     59,023,000,000
#     Securities
#       Proceeds from Sale of Marketable Securities           5,828,000,000     37,446,000,000     47,460,000,000
#       Purchases of Property, Plant and Equipment           10,959,000,000     10,708,000,000     11,085,000,000
#       Payments to Acquire Investments
#       Payments to Acquire Businesses
#       Deferred Revenue
#       Other Investing Activities                            1,337,000,000      2,086,000,000        385,000,000
#       Net Cash Provided by Investing Activities             3,705,000,000    -22,354,000,000    -14,545,000,000
#
#     FINANCING ACTIVITIES:
#       Payments of Tax for Share-based Compensation          5,431,000,000      6,223,000,000      6,556,000,000
#       Dividends Paid                                       15,025,000,000     14,841,000,000     14,467,000,000
#       Repurchases of Common Stock                          77,550,000,000     89,402,000,000     85,971,000,000
#       Proceeds from Issuance of Common Stock
#       Repayments of Long-term Debt                         11,151,000,000      9,543,000,000      8,750,000,000
#       Net Cash Provided by Financing Activities          -108,488,000,000   -110,749,000,000    -93,353,000,000
#
#     Changes in Cash, cash equivalents and restricted        5,760,000,000    -10,952,000,000     -3,860,000,000
#     cash
#     Cash, cash equivalents and restricted cash             30,737,000,000     24,977,000,000     35,929,000,000
#
#                                      Consolidated Statement of Operations
#
#                                                           2023-09-30         2022-09-24         2021-09-25
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     SALES:
#     Total Net Sales                                  383,285,000,000    394,328,000,000    365,817,000,000
#
#     COST OF SALES:
#     Cost Goods and Services Sold                     214,137,000,000    223,546,000,000    212,981,000,000
#
#     Gross Profit                                     169,148,000,000    170,782,000,000    152,836,000,000
#
#     OPERATING EXPENSES:
#       Marketing Expense
#       Research and Development Expenses               29,915,000,000     26,251,000,000     21,914,000,000
#       Selling General and Administrative Expenses     24,932,000,000     25,094,000,000     21,973,000,000
#     Total Operating Expenses                          54,847,000,000     51,345,000,000     43,887,000,000
#
#     Operating Income                                 114,301,000,000    119,437,000,000    108,949,000,000
#
#     OTHER INCOME/EXPENSE:
#       Interest Expense                                 3,933,000,000      2,931,000,000      2,645,000,000
#       Nonoperating Income                               -565,000,000       -334,000,000        258,000,000
#     Income Before Taxes                              113,736,000,000    119,103,000,000    109,207,000,000
#
#     Income Tax Expense                                16,741,000,000     19,300,000,000     14,527,000,000
#     Net Income                                        96,995,000,000     99,803,000,000     94,680,000,000
#
#     EARNINGS PER SHARE:
#       Basic                                                     6.16               6.15               5.67
#       Diluted                                                   6.13               6.11               5.61
#     WEIGHTED AVERAGE SHARES OUTSTANDING:
#       Basic                                           15,744,231,000     16,215,963,000     16,701,272,000
#       Diluted                                         15,812,547,000     16,325,819,000     16,864,919,000

# %% [markdown]
# # **Getting the 10K filings**

# %%
filings = apple.get_filings(form="10-K") #Provides the 10K filings from 1995 to the latest
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Filings for Apple Inc. [320193] ────────────────────────────────────────╮
# │                                                                                                                 │
# │        form   filed        accession_number       xbrl                                                          │
# │  ──────────────────────────────────────────────────────                                                         │
# │   0    10-K   2023-11-03   0000320193-23-000106   ✓                                                             │
# │   1    10-K   2022-10-28   0000320193-22-000108   ✓                                                             │
# │   2    10-K   2021-10-29   0000320193-21-000105   ✓                                                             │
# │   3    10-K   2020-10-30   0000320193-20-000096   ✓                                                             │
# │   4    10-K   2019-10-31   0000320193-19-000119   ✓                                                             │
# │   5    10-K   2018-11-05   0000320193-18-000145   ✓                                                             │
# 15              d10k.htm                                       FORM 10-K
# 16     a2181030z10-k.htm                                            10-K
# 17    a06-25759_210k.htm  ANNUAL REPORT PURSUANT TO SECTION 13 AND 15(D)
# 18    a05-20674_110k.htm  ANNUAL REPORT PURSUANT TO SECTION 13 AND 15(D)
# 19     a2147337z10-k.htm                                            10-K
# 20     a2124888z10-k.htm                                            10-K
# 21     a2096490z10-k.htm                                            10-K
# 22     a2032880z10-k.txt                                       FORM 10-K
# 23                                                                  10-K
# 24                                                                  10-K
# 25
# 26
# 27

# %%
#Retrieving the 5 latest filings (For app usecase)
five_latest_10K = filings.head(5)
five_latest_10K
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────── Filings for Apple Inc. [320193] ────────────────────────────────────────╮
# │                                                                                                                 │
# │       form   filed        accession_number       xbrl                                                           │
# │  ─────────────────────────────────────────────────────                                                          │
# │   0   10-K   2023-11-03   0000320193-23-000106   ✓                                                              │
# │   1   10-K   2022-10-28   0000320193-22-000108   ✓                                                              │
# │   2   10-K   2021-10-29   0000320193-21-000105   ✓                                                              │
# │   3   10-K   2020-10-30   0000320193-20-000096   ✓                                                              │
# │   4   10-K   2019-10-31   0000320193-19-000119   ✓                                                              │
# │                                                                                                                 │
# │ Showing 5 filings of 5 total                                                                                    │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
fl = five_latest_10K.to_pandas()
fl
# Out:
#        accession_number filing_date  reportDate        acceptanceDateTime act  \
# 0  0000320193-23-000106  2023-11-03  2023-09-30  2023-11-02T18:08:27.000Z  34
# 1  0000320193-22-000108  2022-10-28  2022-09-24  2022-10-27T18:01:14.000Z  34
# 2  0000320193-21-000105  2021-10-29  2021-09-25  2021-10-28T18:04:28.000Z  34
# 3  0000320193-20-000096  2020-10-30  2020-09-26  2020-10-29T18:06:25.000Z  34
# 4  0000320193-19-000119  2019-10-31  2019-09-28  2019-10-30T18:12:36.000Z  34
#
#    form fileNumber items      size  isXBRL  isInlineXBRL  \
# 0  10-K  001-36743         9569569       1             1
# 1  10-K  001-36743        10332356       1             1
# 2  10-K  001-36743        10502096       1             1
# 3  10-K  001-36743        12502600       1             1
# 4  10-K  001-36743        12861616       1             1
#
#         primaryDocument primaryDocDescription
# 0     aapl-20230930.htm                  10-K
# 1     aapl-20220924.htm                  10-K
# 2     aapl-20210925.htm                  10-K
# 3     aapl-20200926.htm                  10-K
# 4  a10-k20199282019.htm                  10-K

# %%
#Code to download the 10K filings as pdfs
# !pip install pdfkit
# !pip install weasyprint

# %%
import requests
import os
import time
from weasyprint import HTML

def download_primary_documents(df, download_dir):
    """Downloads primary documents as PDF files from SEC EDGAR filings,
       converting HTML content to PDF using WeasyPrint.

    Args:
        df (pd.DataFrame): DataFrame containing filing information with columns:
            - accession_number: Accession number of the filing.
            - primaryDocument: Name of the primary document file.
        download_dir (str): Directory to save downloaded PDF files.

    Returns:
        None
    """

    base_url = "https://www.sec.gov/Archives/edgar/data/"

    headers = {
        'User-Agent': "Mozilla/5.0"
    }  # Headers to mimic a browser

    for index, row in df.iterrows():
        accession_number = row['accession_number']
        primary_document = row['primaryDocument']

        # Extract company CIK from accession number
        cik = accession_number.split("-")[0]

        # Construct URL directly using primaryDocument
        doc_url = f"{base_url}{cik}/{accession_number.replace('-', '')}/{primary_document}"

        # Download and convert to PDF
        try:
            response = requests.get(doc_url, headers=headers)
            response.raise_for_status()  # Raise an error for bad status codes

            html = HTML(string=response.text)
            filename = f"{accession_number}_{primary_document.replace('.htm', '.pdf')}"
            html.write_pdf(os.path.join(download_dir, filename))

            print(f"Downloaded {filename}")
        except Exception as e:
            print(f"Error downloading or converting {doc_url}: {e}")

        time.sleep(5)  # Add a 5-second delay between requests

# Assuming your DataFrame is named 'df' (replace with your actual DataFrame)
df = fl
download_dir = "content"  # Directory to save downloaded PDF files

if not os.path.exists(download_dir):
    os.makedirs(download_dir)

download_primary_documents(df, download_dir)
# Out:
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20230930_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20230930_g2.jpg">
# Downloaded 0000320193-23-000106_aapl-20230930.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20220924_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20220924_g2.jpg">
# Downloaded 0000320193-22-000108_aapl-20220924.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20210925_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20210925_g2.jpg">
# Downloaded 0000320193-21-000105_aapl-20210925.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20200926_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="aapl-20200926_g2.jpg">
# Downloaded 0000320193-20-000096_aapl-20200926.pdf
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `font-size:pt` at 1:37, invalid value.
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="g66145g66i38.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="chart-06f17b4ddd9352dc8dc.jpg">
# Downloaded 0000320193-19-000119_a10-k20199282019.pdf

# %% [markdown]
# # **Google 10K Filings**

# %%
Google = Company("GOOG")

# %%
Google.financials
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                                Balance Sheet
#
#                                                        2023-12-31         2022-12-31         2021-12-31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     ASSETS:
#     CURRENT ASSETS:
#       Cash and Cash Equivalents                    24,048,000,000     21,879,000,000
#       Short-term Investments
#       Other Current Assets                         12,650,000,000     10,775,000,000
#       Total Current Assets                        171,530,000,000    164,795,000,000
#
#     NONCURRENT ASSETS:
#       Marketable Securities                         1,400,000,000        803,000,000
#       Property, Plant and Equipment               134,345,000,000    112,668,000,000
#       Other Noncurrent Assets                      10,051,000,000      8,707,000,000
#       Total Noncurrent Assets
#
#     Total Assets                                  402,392,000,000    365,264,000,000
#
#     LIABILITIES AND STOCKHOLDERS' EQUITY:
#     CURRENT LIABILITIES:
#       Accounts Payable                              7,493,000,000      5,128,000,000
#       Other Current Liabilities
#       Deferred Revenue                              4,137,000,000      3,908,000,000
#       Commercial Paper                                          0                  0
#       Term Debt                                     1,000,000,000                  0
#       Accrued Liabilities                          46,168,000,000     37,866,000,000
#       Total Current Liabilities                    81,814,000,000     69,300,000,000
#
#     NONCURRENT LIABILITIES:
#       Non-current Long Term Debt
#       Other Noncurrent Liabilities                  1,616,000,000      2,247,000,000
#       Total Noncurrent Liabilities
#
#     Total Liabilities                             119,013,000,000    109,120,000,000
#
#     STOCKHOLDERS' EQUITY:
#       Common Stock and paid-in Capital             76,534,000,000     68,184,000,000
#       Retained Earnings                           211,247,000,000    195,563,000,000
#       Accumulated Other Comprehensive Income       -4,402,000,000     -7,603,000,000
#       Total Stockholders' Equity                  283,379,000,000    256,144,000,000    251,635,000,000
#
#     Total Liabilities and Stockholders' Equity    402,392,000,000    365,264,000,000
#
#                                                 Cashflow Statement
#
#                                                                2023-12-31         2022-12-31         2021-12-31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#

# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
fl = five_latest_10K.to_pandas()
fl
# Out:
#        accession_number filing_date  reportDate        acceptanceDateTime act  \
# 0  0001652044-24-000022  2024-01-31  2023-12-31  2024-01-30T21:43:43.000Z  34
# 1  0001652044-23-000016  2023-02-03  2022-12-31  2023-02-02T21:23:45.000Z  34
# 2  0001652044-22-000019  2022-02-02  2021-12-31  2022-02-01T21:08:02.000Z  34
# 3  0001652044-21-000010  2021-02-03  2020-12-31  2021-02-02T20:12:25.000Z  34
# 4  0001652044-20-000008  2020-02-04  2019-12-31  2020-02-03T21:03:59.000Z  34
#
#    form fileNumber items      size  isXBRL  isInlineXBRL    primaryDocument  \
# 0  10-K  001-37580        13927595       1             1  goog-20231231.htm
# 1  10-K  001-37580        15264470       1             1  goog-20221231.htm
# 2  10-K  001-37580        15044932       1             1  goog-20211231.htm
# 3  10-K  001-37580        14948616       1             1  goog-20201231.htm
# 4  10-K  001-37580        16583126       1             1   goog10-k2019.htm
#
#   primaryDocDescription
# 0                  10-K
# 1                  10-K
# 2                  10-K
# 3                  10-K
# 4                  10-K

# %%
import requests
import os
import time
from weasyprint import HTML

def download_primary_documents(df, download_dir):
    """Downloads primary documents as PDF files from SEC EDGAR filings,
       converting HTML content to PDF using WeasyPrint.

    Args:
        df (pd.DataFrame): DataFrame containing filing information with columns:
            - accession_number: Accession number of the filing.
            - primaryDocument: Name of the primary document file.
        download_dir (str): Directory to save downloaded PDF files.

    Returns:
        None
    """

    base_url = "https://www.sec.gov/Archives/edgar/data/"

    headers = {
        'User-Agent': "Mozilla/5.0"
    }  # Headers to mimic a browser

    for index, row in df.iterrows():
        accession_number = row['accession_number']
        primary_document = row['primaryDocument']

        # Extract company CIK from accession number
        cik = accession_number.split("-")[0]

        # Construct URL directly using primaryDocument
        doc_url = f"{base_url}{cik}/{accession_number.replace('-', '')}/{primary_document}"

        # Download and convert to PDF
        try:
            response = requests.get(doc_url, headers=headers)
            response.raise_for_status()  # Raise an error for bad status codes

            html = HTML(string=response.text)
            filename = f"{accession_number}_{primary_document.replace('.htm', '.pdf')}"
            html.write_pdf(os.path.join(download_dir, filename))

            print(f"Downloaded {filename}")
        except Exception as e:
            print(f"Error downloading or converting {doc_url}: {e}")

        time.sleep(5)  # Add a 5-second delay between requests

# Assuming your DataFrame is named 'df' (replace with your actual DataFrame)
df = fl
download_dir = "GOOGLE"  # Directory to save downloaded PDF files

if not os.path.exists(download_dir):
    os.makedirs(download_dir)

download_primary_documents(df, download_dir)
# Out:
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20231231_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20231231_g2.jpg">
# Downloaded 0001652044-24-000022_goog-20231231.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20221231_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20221231_g2.jpg">
# Downloaded 0001652044-23-000016_goog-20221231.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20211231_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20211231_g2.jpg">
# Downloaded 0001652044-22-000019_goog-20211231.pdf
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20201231_g1.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="goog-20201231_g2.jpg">
# Downloaded 0001652044-21-000010_goog-20201231.pdf
# WARNING:weasyprint:Ignored `background-color:` at 1:20, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:108, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:108, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:23, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:108, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `background-color:` at 1:56, no value.
# WARNING:weasyprint:Ignored `text-align:-moz-right` at 1:70, invalid value.
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="chart-684fc4fa3c835ff7905.jpg">
# ERROR:weasyprint:Relative URI reference without a base URI: <img src="chart-82b0fb3f451859028be.jpg">
# Downloaded 0001652044-20-000008_goog10-k2019.pdf

# %% [markdown]
# # **Amazon 10k filings**

# %%
am = Company("AMZN")

# %%
am.financials
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#
#                                                Balance Sheet
#
#                                                        2023-12-31         2022-12-31         2021-12-31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     ASSETS:
#     CURRENT ASSETS:
#       Cash and Cash Equivalents                    73,387,000,000     53,888,000,000
#       Short-term Investments
#       Other Current Assets
#       Total Current Assets                        172,351,000,000    146,791,000,000
#
#     NONCURRENT ASSETS:
#       Marketable Securities
#       Property, Plant and Equipment
#       Other Noncurrent Assets                      56,024,000,000     42,758,000,000
#       Total Noncurrent Assets
#
#     Total Assets                                  527,854,000,000    462,675,000,000    420,549,000,000
#
#     LIABILITIES AND STOCKHOLDERS' EQUITY:
#     CURRENT LIABILITIES:
#       Accounts Payable                             84,981,000,000     79,600,000,000
#       Other Current Liabilities
#       Deferred Revenue                             15,227,000,000     13,227,000,000
#       Commercial Paper                                          0      6,800,000,000
#       Term Debt                                     8,494,000,000      2,999,000,000
#       Accrued Liabilities                          64,709,000,000     62,566,000,000
#       Total Current Liabilities                   164,917,000,000    155,393,000,000
#
#     NONCURRENT LIABILITIES:
#       Non-current Long Term Debt                   58,314,000,000     67,150,000,000
#       Other Noncurrent Liabilities                 25,451,000,000     21,121,000,000
#       Total Noncurrent Liabilities
#
#     Total Liabilities                                                  4,077,000,000
#
#     STOCKHOLDERS' EQUITY:
#       Common Stock                                    109,000,000        108,000,000
#       Retained Earnings                           113,618,000,000     83,193,000,000
#       Accumulated Other Comprehensive Income       -3,040,000,000     -4,487,000,000
#       Total Stockholders' Equity                  201,875,000,000    146,043,000,000    138,245,000,000
#
#     Total Liabilities and Stockholders' Equity    527,854,000,000    462,675,000,000
#
#                                                 Cashflow Statement
#
#                                                                2023-12-31         2022-12-31         2021-12-31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     OPERATING ACTIVITIES:
#       Net Income                                           30,425,000,000     -2,722,000,000     33,364,000,000
#       Depreciation and Amortization                        48,663,000,000     41,921,000,000     34,433,000,000
#       Stock-based Compensation                             24,023,000,000     19,621,000,000     12,757,000,000
#       Foreign Currency Transaction Gain/Loss                   65,000,000       -340,000,000        -55,000,000
#       Other Noncash Income/Expense                            748,000,000    -16,966,000,000     14,306,000,000
#       Changes in Other Current Assets
#       Changes in Accounts Payable                           5,473,000,000      2,945,000,000      3,602,000,000
#       Changes in Inventories                               -1,449,000,000      2,592,000,000      9,487,000,000
#       Changes in Deferred Revenue                           4,578,000,000      2,216,000,000      2,314,000,000
#       Net Cash Provided by Operating Activities            84,946,000,000     46,752,000,000     46,327,000,000
#
#     INVESTING ACTIVITIES:
#       Purchases of Marketable Securities
#       Proceeds from Maturities of Marketable
#     Securities
#       Proceeds from Sale of Marketable Securities
#       Purchases of Property, Plant and Equipment
#       Payments to Acquire Investments
#       Payments to Acquire Businesses
#       Deferred Revenue                                      4,578,000,000      2,216,000,000      2,314,000,000
#       Other Investing Activities
#       Net Cash Provided by Investing Activities           -49,833,000,000    -37,601,000,000    -58,154,000,000
#
#     FINANCING ACTIVITIES:
#       Payments of Tax for Share-based Compensation
#       Dividends Paid
#       Repurchases of Common Stock                                       0      6,000,000,000                  0
#       Proceeds from Issuance of Common Stock
#       Repayments of Long-term Debt                          3,676,000,000      1,258,000,000      1,590,000,000
#       Net Cash Provided by Financing Activities           -15,879,000,000      9,718,000,000      6,291,000,000
#
#     Changes in Cash, cash equivalents and restricted       19,637,000,000     17,776,000,000     -5,900,000,000
#     cash
#     Cash, cash equivalents and restricted cash             73,890,000,000     54,253,000,000     36,477,000,000
#
#                                  Consolidated Statement of Operations
#
#                                                   2023-12-31         2022-12-31         2021-12-31
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#     SALES:
#     Revenue                                                       1,658,000,000         55,000,000
#
#     COST OF SALES:
#     Cost Goods and Services Sold             304,739,000,000    288,831,000,000    272,344,000,000
#
#     Gross Profit                                                 -3,123,000,000       -465,000,000
#
#     OPERATING EXPENSES:
#       Marketing Expense                       44,370,000,000     42,238,000,000     32,551,000,000
#       Research and Development Expenses
#       General and Administrative Expenses     11,816,000,000     11,891,000,000      8,823,000,000
#     Total Operating Expenses
#
#     Operating Income                          36,852,000,000     12,248,000,000     24,879,000,000
#
#     OTHER INCOME/EXPENSE:
#       Interest Expense                         3,182,000,000      2,367,000,000      1,809,000,000
#       Nonoperating Income                        705,000,000    -18,184,000,000     13,272,000,000
#     Income Before Taxes
#
#     Income Tax Expense                         7,120,000,000     -3,217,000,000      4,791,000,000
#     Net Income                                30,425,000,000     -2,722,000,000     33,364,000,000
#
#     EARNINGS PER SHARE:
#       Basic                                             2.95              -0.27               3.30
#       Diluted                                           2.90              -0.27               3.24
#     WEIGHTED AVERAGE SHARES OUTSTANDING:
#       Basic                                   10,304,000,000     10,189,000,000     10,117,000,000
#       Diluted                                 10,492,000,000     10,189,000,000     10,296,000,000

# %%
filings = am.get_filings(form="10-K")
filings
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────── Filings for AMAZON COM INC [1018724] ──────────────────────────────────────╮
# │                                                                                                                 │
# │        form   filed        accession_number       xbrl                                                          │
# │  ──────────────────────────────────────────────────────                                                         │
# │   0    10-K   2024-02-02   0001018724-24-000008   ✓                                                             │
# │   1    10-K   2023-02-03   0001018724-23-000004   ✓                                                             │
# │   2    10-K   2022-02-04   0001018724-22-000005   ✓                                                             │
# │   3    10-K   2021-02-03   0001018724-21-000004   ✓                                                             │
# │   4    10-K   2020-01-31   0001018724-20-000004   ✓                                                             │
# │   5    10-K   2019-02-01   0001018724-19-000004   ✓                                                             │
# │   6    10-K   2018-02-02   0001018724-18-000005   ✓                                                             │
# │   7    10-K   2017-02-10   0001018724-17-000011   ✓                                                             │

# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯

# %%
fl = five_latest_10K.to_pandas()
fl
# Out:
#        accession_number filing_date  reportDate        acceptanceDateTime act  \
# 0  0001018724-24-000008  2024-02-02  2023-12-31  2024-02-01T18:48:30.000Z  34
# 1  0001018724-23-000004  2023-02-03  2022-12-31  2023-02-02T18:27:34.000Z  34
# 2  0001018724-22-000005  2022-02-04  2021-12-31  2022-02-03T18:46:51.000Z  34
# 3  0001018724-21-000004  2021-02-03  2020-12-31  2021-02-02T19:44:10.000Z  34
# 4  0001018724-20-000004  2020-01-31  2019-12-31  2020-01-30T20:46:13.000Z  34
#
#    form fileNumber items      size  isXBRL  isInlineXBRL  \
# 0  10-K  000-22513        12110804       1             1
# 1  10-K  000-22513        12809287       1             1
# 2  10-K  000-22513        13441589       1             1
# 3  10-K  000-22513        12093058       1             1
# 4  10-K  000-22513        13336980       1             1
#
#          primaryDocument primaryDocDescription
# 0      amzn-20231231.htm                  10-K
# 1      amzn-20221231.htm                  10-K
# 2      amzn-20211231.htm                  10-K
# 3      amzn-20201231.htm                  10-K
# 4  amzn-20191231x10k.htm                  10-K

# %%
import requests
import os
import time
from weasyprint import HTML

def download_primary_documents(df, download_dir):
    """Downloads primary documents as PDF files from SEC EDGAR filings,
       converting HTML content to PDF using WeasyPrint.

    Args:
        df (pd.DataFrame): DataFrame containing filing information with columns:
            - accession_number: Accession number of the filing.
            - primaryDocument: Name of the primary document file.
        download_dir (str): Directory to save downloaded PDF files.

    Returns:
        None
    """

    base_url = "https://www.sec.gov/Archives/edgar/data/"

    headers = {
        'User-Agent': "Mozilla/5.0"
    }  # Headers to mimic a browser

    for index, row in df.iterrows():
        accession_number = row['accession_number']
        primary_document = row['primaryDocument']

        # Extract company CIK from accession number
        cik = accession_number.split("-")[0]

        # Construct URL directly using primaryDocument
        doc_url = f"{base_url}{cik}/{accession_number.replace('-', '')}/{primary_document}"

        # Download and convert to PDF
        try:
            response = requests.get(doc_url, headers=headers)
            response.raise_for_status()  # Raise an error for bad status codes

            html = HTML(string=response.text)
            filename = f"{accession_number}_{primary_document.replace('.htm', '.pdf')}"
            html.write_pdf(os.path.join(download_dir, filename))

            print(f"Downloaded {filename}")
        except Exception as e:
            print(f"Error downloading or converting {doc_url}: {e}")

        time.sleep(5)  # Add a 5-second delay between requests

# Assuming your DataFrame is named 'df' (replace with your actual DataFrame)
df = fl
download_dir = "content"  # Directory to save downloaded PDF files

if not os.path.exists(download_dir):
    os.makedirs(download_dir)

download_primary_documents(df, download_dir)
# Out:
# Downloaded 0001018724-24-000008_amzn-20231231.pdf
# Downloaded 0001018724-23-000004_amzn-20221231.pdf
# Downloaded 0001018724-22-000005_amzn-20211231.pdf
# Downloaded 0001018724-21-000004_amzn-20201231.pdf
# Downloaded 0001018724-20-000004_amzn-20191231x10k.pdf
